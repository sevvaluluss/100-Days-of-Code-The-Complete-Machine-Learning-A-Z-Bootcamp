# %% [markdown]
# <a href="https://colab.research.google.com/github/sevvaluluss/100-Days-of-Code-The-Complete-Python-Pro-Bootcamp/blob/main/Predicting_Salary_with_simple_linear_regression_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the libraries

# %%
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression #dataları training etmek için skcitlearn kütüphanesini kullanıyoruz
regressor = LinearRegression() #basit dogrusal regresyon modelini bu satırda oluşturduk.
regressor.fit(X_train, y_train)                #regressor.fit() verileri training etmek için kulanılan bir fonksiyondur.
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regressor.predict(X_test) #y yi tahmin eden vektorleri oluşturduk
y_pred
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(X_train, y_train, color="red") #noktasal olarak train edilen verileri gösterir
plt.plot(X_train, regressor.predict(X_train), color="blue")
plt.title("Salary vs Experinece(Training set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
plt.scatter(X_test, y_test, color="red") #noktasal olarak train edilen verileri gösterir
plt.plot(X_train, regressor.predict(X_train), color="blue")
plt.title("Salary vs Experinece(Test set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()
